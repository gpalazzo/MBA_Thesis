# %%
# %reload_kedro
# Out:
# 2023-08-21 14:33:47,129 - kedro.extras.extensions.ipython - INFO - No path argument was provided. Using: /Users/gpalazzo/Desktop/dev/mba_Otavio
# 2023-08-21 14:33:47,463 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# 2023-08-21 14:33:47,638 - kedro.extras.extensions.ipython - INFO - ** Kedro project itaete_buy_prop
# 2023-08-21 14:33:47,639 - kedro.extras.extensions.ipython - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2023-08-21 14:33:47,650 - kedro.extras.extensions.ipython - INFO - Registered line magic `run_viz`

# %%
# aqui tanto faz ser treino ou teste, o importante são as variáveis
X_test = catalog.load("master_table_teste_ftes")

vif = catalog.load("master_table_multic_vif_values")
# Out:
# 2023-08-21 14:34:28,480 - kedro.io.data_catalog - INFO - Loading data from `master_table_teste_ftes` (ParquetDataSet)...
# 2023-08-21 14:34:28,496 - kedro.io.data_catalog - INFO - Loading data from `master_table_multic_vif_values` (ParquetDataSet)...

# %%
features = X_test.columns.tolist()

vif_ftes = vif[vif["features"].isin(features)]

# %%
sorted(vif_ftes["features"]) == sorted(features)
# Out:
# True

# %%
vif_ftes.sort_values(by="vif", ascending=False)
# Out:
#                                              features       vif
# 3                                 valor_total_compras  8.641899
# 23                     janela1__diesel_logrets_cumsum  7.678952
# 12                                      receita_media  7.667880
# 42  janela12__relacao_volume_concessionario_pelo_p...  7.431231
# 43  janela1__relacao_volume_concessionario_pelo_pr...  6.129594
# 44  janela6__relacao_volume_concessionario_pelo_pr...  5.306907
# 13                                        custo_medio  5.234415
# 14                    janela12__usdbrl_pxclose_cumsum  3.509880
# 18                     janela1__usdbrl_pxclose_cumsum  2.636495
# 0                            tempo_medio_dias_compras  2.472786
# 16                     janela6__usdbrl_pxclose_cumsum  2.001778
# 15             janela12__usdbrl_pxhighlow_diff_cumsum  1.876387
# 19              janela1__usdbrl_pxhighlow_diff_cumsum  1.621709
# 17              janela6__usdbrl_pxhighlow_diff_cumsum  1.607821
# 4                              dif_dias_ultima_compra  1.520740

# %%
vif.sort_values(by="vif", ascending=False)
# Out:
#                                              features          vif
# 2                               linha_credito__pronaf          inf
# 1                             potencial_do_cliente__c          inf
# 5                             potencial_do_cliente__b          inf
# 6                           linha_credito__moderfrota          inf
# 7                             potencial_do_cliente__a          inf
# 8                               linha_credito__finame          inf
# 9                      linha_credito__recurso_proprio          inf
# 10                          potencial_do_cliente__pan          inf
# 11                           linha_credito__consorcio          inf
# 38    janela1__px_trator_pot_5090e_cab_9x3_SMA_30dias  1697.747886
# 37    janela6__px_trator_pot_5090e_cab_9x3_SMA_30dias  1609.538455
# 29                    janela6__laranja_logrets_cumsum   886.487067
# 41  janela1__px_trator_cxlrj_5090e_cab_9x3_SMA_30dias   869.117108
# 22                       janela12__preco_medio_diesel   837.672695
# 39  janela6__px_trator_cxlrj_5090e_cab_9x3_SMA_30dias   754.834494
# 21                        janela12__diesel_SMA_30dias   747.522904
# 33                        janela1__laranja_SMA_30dias   602.402679
# 36                                        selic_media   512.090294
# 34                       janela1__preco_medio_laranja   460.328215
# 24                         janela1__diesel_SMA_30dias   453.179968
# 25                        janela1__preco_medio_diesel   445.946902
# 26                   janela12__laranja_logrets_cumsum   436.363155
# 30                        janela6__laranja_SMA_30dias   333.050565
# 31                       janela6__preco_medio_laranja   320.543121
# 28                      janela12__preco_medio_laranja   279.246599
# 40  janela12__px_trator_cxlrj_5090e_cab_9x3_SMA_30...   184.549825
# 32                    janela1__laranja_logrets_cumsum   179.976437
# 27                       janela12__laranja_SMA_30dias   102.666413
# 35                                         ipca_medio    87.842317
# 20                    janela12__diesel_logrets_cumsum    54.959396
# 3                                 valor_total_compras     8.641899
# 23                     janela1__diesel_logrets_cumsum     7.678952
# 12                                      receita_media     7.667880
# 42  janela12__relacao_volume_concessionario_pelo_p...     7.431231
# 43  janela1__relacao_volume_concessionario_pelo_pr...     6.129594
# 44  janela6__relacao_volume_concessionario_pelo_pr...     5.306907
# 13                                        custo_medio     5.234415
# 14                    janela12__usdbrl_pxclose_cumsum     3.509880
# 18                     janela1__usdbrl_pxclose_cumsum     2.636495
# 0                            tempo_medio_dias_compras     2.472786
# 16                     janela6__usdbrl_pxclose_cumsum     2.001778
# 15             janela12__usdbrl_pxhighlow_diff_cumsum     1.876387
# 19              janela1__usdbrl_pxhighlow_diff_cumsum     1.621709
# 17              janela6__usdbrl_pxhighlow_diff_cumsum     1.607821
# 4                              dif_dias_ultima_compra     1.520740
